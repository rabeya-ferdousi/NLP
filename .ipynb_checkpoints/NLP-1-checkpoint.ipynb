# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
from sklearn.decomposition import PCA

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import gensim.downloader as api
#       2 from gensim.models import KeyedVectors
#
# ModuleNotFoundError: No module named 'gensim'

# %%
#pip install testfixtures

# %%
pip install testfixtures
# Out:
# ...
#                                               0.0/102.4 kB ? eta -:--:--
#      -----------                             30.7/102.4 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------  102.4/102.4 kB 1.2 MB/s eta 0:00:01
#      ------------------------------------ 102.4/102.4 kB 980.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#
# ...
#                                               0.0/2.1 MB ? eta -:--:--
#                                               0.0/2.1 MB ? eta -:--:--
#      --                                       0.1/2.1 MB 1.6 MB/s eta 0:00:02
#      ---                                      0.2/2.1 MB 1.8 MB/s eta 0:00:02
#      ------                                   0.3/2.1 MB 2.1 MB/s eta 0:00:01
#      ---------                                0.5/2.1 MB 2.3 MB/s eta 0:00:01
#      -----------                              0.6/2.1 MB 2.4 MB/s eta 0:00:01
#      ------------                             0.6/2.1 MB 2.3 MB/s eta 0:00:01
#      -------------                            0.7/2.1 MB 2.0 MB/s eta 0:00:01
#      -------------                            0.7/2.1 MB 1.8 MB/s eta 0:00:01
#      -------------                            0.7/2.1 MB 1.8 MB/s eta 0:00:01
#      ---------------                          0.8/2.1 MB 1.7 MB/s eta 0:00:01
# ...

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import gensim.downloader as api
#       2 from gensim.models import KeyedVectors
#
# ModuleNotFoundError: No module named 'gensim'

# %%
pip install gensim
# Out:
# ...
#      ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/24.0 MB 1.4 MB/s eta 0:00:18
#      ---------------------------------------- 0.1/24.0 MB 1.3 MB/s eta 0:00:19
#      ---------------------------------------- 0.2/24.0 MB 1.6 MB/s eta 0:00:16
#      ---------------------------------------- 0.3/24.0 MB 1.6 MB/s eta 0:00:15
#       --------------------------------------- 0.5/24.0 MB 2.0 MB/s eta 0:00:12
#       --------------------------------------- 0.5/24.0 MB 2.0 MB/s eta 0:00:12
#       --------------------------------------- 0.6/24.0 MB 1.9 MB/s eta 0:00:13
#       --------------------------------------- 0.6/24.0 MB 1.9 MB/s eta 0:00:13
#       --------------------------------------- 0.6/24.0 MB 1.4 MB/s eta 0:00:17
#       --------------------------------------- 0.6/24.0 MB 1.4 MB/s eta 0:00:17
#       --------------------------------------- 0.6/24.0 MB 1.4 MB/s eta 0:00:17
# ...

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors

# %%
model = api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# #model = api.load("glove-wiki-gigaword-100") a dataset from hugging face for Word vector understanding.Pre-trained glove vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased."2B tweets" refers to a dataset of 2 billion (2B) tweets. In the context of Natural Language Processing (NLP) and machine learning, datasets like these are often used to train and evaluate models for various tasks related to analyzing and understanding human language. The dataset likely contains a massive collection of tweets, which are short messages posted on platforms like Twitter. Such datasets are valuable resources for training large language models, sentiment analysis, language generation, text classification, and other NLP tasks, as they provide a diverse range of real-world language usage.

# %%
print(model)
# Out:
# KeyedVectors<vector_size=100, 400000 keys>

# %%
#pip install transformers

# %%
print(type(model))
# Out:
# <class 'gensim.models.keyedvectors.KeyedVectors'>

# %%
model['bread'] #printed all the vector value
# Out:
# array([-0.66146  ,  0.94335  , -0.72214  ,  0.17403  , -0.42524  ,
#         0.36303  ,  1.0135   , -0.14802  ,  0.25817  , -0.20326  ,
#        -0.64338  ,  0.16632  ,  0.61518  ,  1.397    , -0.094506 ,
#         0.0041843, -0.18976  , -0.55421  , -0.39371  , -0.22501  ,
#        -0.34643  ,  0.32076  ,  0.34395  , -0.7034   ,  0.23932  ,
#         0.69951  , -0.16461  , -0.31819  , -0.34034  , -0.44906  ,
#        -0.069667 ,  0.35348  ,  0.17498  , -0.95057  , -0.2209   ,
#         1.0647   ,  0.23231  ,  0.32569  ,  0.47662  , -1.1206   ,
#         0.28168  , -0.75172  , -0.54654  , -0.66337  ,  0.34804  ,
#        -0.69058  , -0.77092  , -0.40167  , -0.069351 , -0.049238 ,
#        -0.39351  ,  0.16735  , -0.14512  ,  1.0083   , -1.0608   ,
#        -0.87314  , -0.29339  ,  0.68278  ,  0.61634  , -0.088844 ,
#         0.88094  ,  0.099809 , -0.27161  , -0.58026  ,  0.50364  ,
#        -0.93814  ,  0.67576  , -0.43124  , -0.10517  , -1.2404   ,
# ...

# %%
model.most_similar('usa')
# Out:
# [('canada', 0.6544384956359863),
#  ('america', 0.645224392414093),
#  ('u.s.a.', 0.6184033751487732),
#  ('united', 0.6017189621925354),
#  ('states', 0.5970699191093445),
#  ('australia', 0.5838716626167297),
#  ('world', 0.5590084195137024),
#  ('2010', 0.5580702424049377),
#  ('2012', 0.5504006743431091),
#  ('davis', 0.5464468002319336)]

# %%
model.most_similar(negative='banana')
# Out:
# [('shunichi', 0.49618104100227356),
#  ('ieronymos', 0.4736502170562744),
#  ('pengrowth', 0.4668096601963043),
#  ('höss', 0.4636845588684082),
#  ('damaskinos', 0.4617849290370941),
#  ('yadin', 0.4617374837398529),
#  ('hundertwasser', 0.4588957726955414),
#  ('ncpa', 0.4577339291572571),
#  ('maccormac', 0.4566109776496887),
#  ('rothfeld', 0.4523947238922119)]

# %%
result = model.most_similar(positive=['woman','king'],negative=['man'])
print(result)
# Out:
# [('queen', 0.7698540687561035), ('monarch', 0.6843381524085999), ('throne', 0.6755736470222473), ('daughter', 0.6594556570053101), ('princess', 0.6520534157752991), ('prince', 0.6517034769058228), ('elizabeth', 0.6464517712593079), ('mother', 0.631171703338623), ('emperor', 0.6106470823287964), ('wife', 0.6098655462265015)]

# %%
def analogy(x1,x2,y1):
    result = model.most_similar(positive=[y1,x2],negative=[x1])
    return result[0][0]

# %%
analogy('man','king','woman')
# Out:
# 'queen'

# %%
analogy('tall','tallest','long')
# Out:
# 'longest'

# %%
analogy('book','pen','pencil')
# Out:
# 'highlighter'

# %%
analogy('laptop','wifi','mobile')
# Out:
# 'wireless'

# %%
analogy('sentence','word','vector')
# Out:
# 'vectors'
